# %% [markdown]
# ![Artboard%201-removebg-preview.jpg](attachment:Artboard%201-removebg-preview.jpg)

# %% [markdown]
# # <CENTER> <span style="color: red">**<u>Virtual Internship Program</u>**</span></CENTER>

# %% [markdown]
# ##  <span style="color:blue">  *Author :- Mohd Farman*</span>
# ##  <span style="color:blue">*Beginer Level Tasks*</span>

# %% [markdown]
# ## Image to Pencil Sketch with Python:
# we need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ### Import Libraries

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
print("Necessary packages included successfully!")
# Out:
# Necessary packages included successfully!

# %% [markdown]
# ### loading The Image

# %%
image=cv2.imread("dog.webp")
image = cv2.resize(image,(1000,800))
image
# Out:
# array([[[ 23,  28,  80],
#         [ 23,  28,  80],
#         [ 23,  28,  80],
#         ...,
#         [251, 250, 239],
#         [251, 250, 239],
#         [251, 250, 239]],
#
#        [[ 24,  30,  81],
#         [ 24,  30,  81],
#         [ 24,  30,  81],
#         ...,
#         [251, 250, 239],
#         [251, 250, 239],
#         [251, 250, 239]],
#
#        [[ 26,  33,  82],
#         [ 26,  33,  82],
#         [ 26,  33,  82],
#         ...,
#         [251, 250, 239],
#         [251, 250, 239],
#         [251, 250, 239]],
#
#        ...,
#
#        [[144, 134, 122],
#         [144, 134, 122],
#         [144, 134, 122],
#         ...,
#         [207, 202, 198],
#         [207, 202, 198],
#         [207, 202, 198]],
#
#        [[144, 134, 122],
#         [144, 134, 122],
#         [144, 134, 122],
#         ...,
#         [207, 202, 198],
#         [207, 202, 198],
#         [207, 202, 198]],
#
#        [[144, 134, 122],
#         [144, 134, 122],
#         [144, 134, 122],
#         ...,
#         [207, 202, 198],
#         [207, 202, 198],
#         [207, 202, 198]]], dtype=uint8)

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ###  Gray Scale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[ 43,  43,  43, ..., 247, 247, 247],
#        [ 45,  45,  45, ..., 247, 247, 247],
#        [ 47,  47,  47, ..., 247, 247, 247],
#        ...,
#        [132, 132, 132, ..., 201, 201, 201],
#        [132, 132, 132, ..., 201, 201, 201],
#        [132, 132, 132, ..., 201, 201, 201]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# ### Inverting the image

# %%
inverted_image = cv2.bitwise_not(gray_image)
inverted_image
# Out:
# array([[212, 212, 212, ...,   8,   8,   8],
#        [210, 210, 210, ...,   8,   8,   8],
#        [208, 208, 208, ...,   8,   8,   8],
#        ...,
#        [123, 123, 123, ...,  54,  54,  54],
#        [123, 123, 123, ...,  54,  54,  54],
#        [123, 123, 123, ...,  54,  54,  54]], dtype=uint8)

# %%
plt.imshow(inverted_image)

# %% [markdown]
# ### Smoothing the image

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
img_smoothing
# Out:
# array([[206, 206, 206, ...,   8,   8,   8],
#        [206, 206, 205, ...,   8,   8,   8],
#        [205, 205, 205, ...,   8,   8,   8],
#        ...,
#        [124, 124, 124, ...,  54,  54,  54],
#        [123, 123, 123, ...,  54,  54,  54],
#        [123, 123, 123, ...,  54,  54,  54]], dtype=uint8)

# %%
plt.imshow(img_smoothing)

# %% [markdown]
# ### Inverting the Image to get the Pencil Sketch

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)
pencil_sketch = dodgeV2(gray_image, img_smoothing)
plt.imshow(pencil_sketch)

# %% [markdown]
# ### Comparing the Original Image with Pencil Sketch

# %%
display(Image.fromarray(img_rgb))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x800 at 0x27DBB923340>
# <PIL.Image.Image image mode=L size=1000x800 at 0x27DBB48F3A0>

# %%
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)

# %% [markdown]
# # thank you..
